# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,classification_report

# %%
df = pd.read_csv("Level_2.csv")
df.head(2)
# Out:
#   History_Chronic_Diseases Past_Cancer_Diagnosis Family_History_Other_Cancers  \
# 0                      Low     More than 5 times                        never
# 1                      Low     less than 5 times               Chronic cancer
#
#    Persistent_Cough_Duration_weeks Unusual_Bleeding  \
# 0                         8.659970         Severely
# 1                         9.849549        Sometimes
#
#    Swollen_Lymph_Nodes_Duration_weeks  Recurring_Infections_Count_year  \
# 0                           31.937003                         7.229164
# 1                           24.246782                         5.909125
#
#   Radiation_Exposure Occupational_Hazard_Exposure  \
# 0             Rarely                       Rarely
# 1           Severely                     Severely
#
#   Chronic_Inflammation_History         Immunity  Cancer_Risk_Level
# 0                    Low level  Might be Strong                  0
# ...

# %%
df["History_Chronic_Diseases"] = df["History_Chronic_Diseases"].map({"Low": 1, "Yes Medium": 2, "Yes Severe": 3})
df["Past_Cancer_Diagnosis"] = df["Past_Cancer_Diagnosis"].map({"More than 5 times":1,"less than 5 times":2,"Never":3})
df["Family_History_Other_Cancers"] = df["Family_History_Other_Cancers"].map({"never":1,"Basic cancer":2,"Chronic cancer":3})
df["Unusual_Bleeding"] = df["Unusual_Bleeding"].map({"Never":1,"Sometimes":2,"Severely":3})
df["Radiation_Exposure"] = df["Radiation_Exposure"].map({"Rarely":1,"Sometimes":2,"Severely":3})
df["Occupational_Hazard_Exposure"] = df["Occupational_Hazard_Exposure"].map({"Sometime":1,"Rarely":2,"Severely":3})
df["Immunity"] = df["Immunity"].map({"Feels ok":1,"Might be Strong":2,"Feeling weak":3})
df["Chronic_Inflammation_History"] = df["Chronic_Inflammation_History"].map({"High level":1,"Medium level":2,"Low level":3})
#df["Cancer_Risk_Level"] = df["Cancer_Risk_Level"].map({"High":0,"Medium":2,"Low":1})

# %%
y = df["Cancer_Risk_Level"]
x = df.drop("Cancer_Risk_Level",axis=1)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(x_train.shape, x_test.shape)
# Out:
# (103, 11) (26, 11)

# %%
x_test = x_test[x_train.columns]  # Reorder columns if needed
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 124    2
# 125    2
# 126    2
# 127    2
# 128    2
# Name: Cancer_Risk_Level, Length: 129, dtype: int64

# %%
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
clr = RandomForestClassifier(n_estimators=100,random_state=42)
clr.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = clr.predict(x_test)

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 1.0

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       1.00      1.00      1.00         7
#            2       1.00      1.00      1.00         4
#
#     accuracy                           1.00        26
#    macro avg       1.00      1.00      1.00        26
# weighted avg       1.00      1.00      1.00        26

# %%
import joblib

# %%
joblib.dump(clr,"newcancer_risk_prediction_model_level2.pkl")
# Out:
# ['newcancer_risk_prediction_model_level2.pkl']

# %%
joblib.dump(scaler,"newscaler_level2.pkl")
# Out:
# ['newscaler_level2.pkl']

# %%
x_train
# Out:
#      History_Chronic_Diseases  Past_Cancer_Diagnosis  \
# 70                          1                      3
# 78                          2                      3
# 47                          2                      1
# 0                           1                      1
# 12                          1                      3
# ..                        ...                    ...
# 106                         2                      1
# 14                          3                      2
# 92                          2                      1
# 51                          2                      3
# 102                         2                      1
#
#      Family_History_Other_Cancers  Persistent_Cough_Duration_weeks  \
# 70                              1                         5.644399
# 78                              1                         3.684112
# 47                              3                         8.399224
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, accuracy_score
import joblib

# Load the dataset
df = pd.read_csv('Level_02.csv')

# Feature Engineering: Map categorical values to integers
df["History_Chronic_Diseases"] = df["History_Chronic_Diseases"].map({"Low": 1, "Yes Medium": 2, "Yes Severe": 3})
df["Past_Cancer_Diagnosis"] = df["Past_Cancer_Diagnosis"].map({"More than 5 times": 1, "less than 5 times": 2, "Never": 3})
df["Family_History_Other_Cancers"] = df["Family_History_Other_Cancers"].map({"never": 1, "Basic cancer": 2, "Chronic cancer": 3})
df["Unusual_Bleeding"] = df["Unusual_Bleeding"].map({"Never": 1, "Sometimes": 2, "Severely": 3})
df["Radiation_Exposure"] = df["Radiation_Exposure"].map({"Rarely": 1, "Sometimes": 2, "Severely": 3})
df["Occupational_Hazard_Exposure"] = df["Occupational_Hazard_Exposure"].map({"Sometime": 1, "Rarely": 2, "Severely": 3})
df["Immunity"] = df["Immunity"].map({"Feels ok": 1, "Might be Strong": 2, "Feeling weak": 3})
df["Chronic_Inflammation_History"] = df["Chronic_Inflammation_History"].map({"High level": 1, "Medium level": 2, "Low level": 3})
#df["Cancer_Risk_Level"] = df["Cancer_Risk_Level"].map({"High": 0, "Medium": 2, "Low": 1})

# Define features and target
X = df.drop("Cancer_Risk_Level", axis=1)
y = df["Cancer_Risk_Level"]

# Scale numerical features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Train a Logistic Regression model
model = LogisticRegression(max_iter=1000, class_weight='balanced')
model.fit(X_train, y_train)

# Evaluate the model
y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))

# Save the model and the scaler
joblib.dump(model, 'newcancer_risk_prediction_model_level2.pkl')
joblib.dump(scaler, "newscaler_level2.pkl")

print("Logistic Regression model and scaler saved successfully.")
# Out:
# Accuracy: 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        42
#            1       1.00      1.00      1.00        10
#            2       1.00      1.00      1.00        48
#
#     accuracy                           1.00       100
#    macro avg       1.00      1.00      1.00       100
# weighted avg       1.00      1.00      1.00       100
#
# Logistic Regression model and scaler saved successfully.
