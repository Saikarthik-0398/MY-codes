# %%
import pickle
import pandas as pd

# %%
df = pd.read_csv("Cancer.csv")

# %%
df.head()
# Out:
#   Patient Id  Age  Gender  AirPollution  Alcoholuse  DustAllergy  \
# 0         P1   33       1             2           4            5
# 1        P10   17       1             3           1            5
# 2       P100   35       1             4           5            6
# 3      P1000   37       1             7           7            7
# 4       P101   46       1             6           8            7
#
#    OccuPationalHazards  GeneticRisk  chronicLungDisease  BalancedDiet  ...  \
# 0                    4            3                   2             2  ...
# 1                    3            4                   2             2  ...
# 2                    5            5                   4             6  ...
# 3                    7            6                   7             7  ...
# 4                    7            7                   6             7  ...
#
#    Fatigue  WeightLoss  ShortnessofBreath  Wheezing  SwallowingDifficulty  \
# ...

# %%
df.columns
# Out:
# Index(['Patient Id', 'Age', 'Gender', 'AirPollution', 'Alcoholuse',
#        'DustAllergy', 'OccuPationalHazards', 'GeneticRisk',
#        'chronicLungDisease', 'BalancedDiet', 'Obesity', 'Smoking',
#        'PassiveSmoker', 'ChestPain', 'CoughingofBlood', 'Fatigue',
#        'WeightLoss', 'ShortnessofBreath', 'Wheezing', 'SwallowingDifficulty',
#        'ClubbingofFingerNails', 'FrequentCold', 'DryCough', 'Snoring',
#        'Level'],
#       dtype='object')

# %%
df = df.drop(['Patient Id','Age', 'Gender', 'AirPollution','OccuPationalHazards','BalancedDiet', 'Obesity','PassiveSmoker','Wheezing','ClubbingofFingerNails','Snoring'],axis=1)

# %%
df= df.drop("DustAllergy",axis=1)

# %%
y = df['Level']

# %%
x = df.drop("Level",axis=1)

# %%
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,classification_report

# %%
labelencoder = LabelEncoder()
y = labelencoder.fit_transform(y)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)
x_test  = scaler.transform(x_test)

# %%
clr = RandomForestClassifier(n_estimators=100)
clr.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = clr.predict(x_test)
print(accuracy_score(y_test,y_pred)*100,"%")
# Out:
# 100.0 %

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        82
#            1       1.00      1.00      1.00        63
#            2       1.00      1.00      1.00        55
#
#     accuracy                           1.00       200
#    macro avg       1.00      1.00      1.00       200
# weighted avg       1.00      1.00      1.00       200

# %%
with open("random.pkl", "wb") as file:  # Open file in write-binary mode
    pickle.dump(clr, file)

# %%
with open("scalerrandom.pkl", "wb") as file:  # Open file in write-binary mode
    pickle.dump(scaler, file)

# %%
with open("label.pkl", "wb") as file:  # Open file in write-binary mode
    pickle.dump(labelencoder, file)

# %%
x_train
# Out:
# array([[-0.95411292, -1.21064653, -0.19869073, ...,  0.97788064,
#          0.24805407, -0.91476416],
#        [-0.95411292, -1.68471271, -1.29491547, ...,  0.09789806,
#         -1.38298641, -0.91476416],
#        [-1.33556736, -0.26251415, -0.7468031 , ..., -1.22207581,
#         -0.29562609, -1.40690359],
#        ...,
#        [-0.57265848, -0.73658034, -1.29491547, ...,  0.53788935,
#         -0.83930625, -0.42262473],
#        [ 1.33461372,  1.15968441,  0.89753401, ..., -1.22207581,
#         -0.29562609,  0.06951469],
#        [ 1.33461372,  1.15968441,  0.89753401, ..., -1.22207581,
#         -0.29562609,  0.06951469]])

# %%
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
import numpy as np

# Load and preprocess the data
df = pd.read_csv("Cancer.csv")
df = df.drop(['Patient Id', 'Age', 'Gender', 'AirPollution', 'OccuPationalHazards',
              'BalancedDiet', 'Obesity', 'PassiveSmoker', 'Wheezing',
              'ClubbingofFingerNails', 'Snoring'], axis=1)
df = df.drop("DustAllergy", axis=1)

# Separate features and target
y = df['Level']
x = df.drop("Level", axis=1)

# Encode the labels
labelencoder = LabelEncoder()
y = labelencoder.fit_transform(y)

# Split the data
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Scale the features
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# Build a simple neural network model
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(x_train.shape[1],)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(len(np.unique(y)), activation='softmax')  # Softmax for multi-class classification
])

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=10, batch_size=32, validation_split=0.2)

# Evaluate the model
loss, accuracy = model.evaluate(x_test, y_test)
print(f"Test Loss: {loss}, Test Accuracy: {accuracy}")

# Save the model as a TensorFlow Lite model
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the TFLite model to a file
with open("cancer_model.tflite", "wb") as f:
    f.write(tflite_model)

print("TFLite model created successfully!")
# Out:
# Epoch 1/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.5537 - loss: 0.9648 - val_accuracy: 0.8687 - val_loss: 0.6406
# Epoch 2/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9142 - loss: 0.5916 - val_accuracy: 0.9438 - val_loss: 0.4163
# Epoch 3/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9452 - loss: 0.3867 - val_accuracy: 0.9500 - val_loss: 0.2873
# Epoch 4/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9441 - loss: 0.2627 - val_accuracy: 0.9500 - val_loss: 0.2115
# Epoch 5/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9574 - loss: 0.1820 - val_accuracy: 0.9563 - val_loss: 0.1696
# Epoch 6/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9620 - loss: 0.1481 - val_accuracy: 0.9812 - val_loss: 0.1418
# Epoch 7/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9816 - loss: 0.1032 - val_accuracy: 0.9812 - val_loss: 0.1222
# Epoch 8/10
# ...

# %%
df
# Out:
#      Alcoholuse  GeneticRisk  chronicLungDisease  Smoking  ChestPain  \
# 0             4            3                   2        3          2
# 1             1            4                   2        2          2
# 2             5            5                   4        2          4
# 3             7            6                   7        7          7
# 4             8            7                   6        8          7
# ..          ...          ...                 ...      ...        ...
# 995           7            7                   6        7          7
# 996           8            7                   6        7          7
# 997           5            5                   4        2          4
# 998           8            7                   6        8          7
# 999           5            5                   4        2          4
#
#      CoughingofBlood  Fatigue  WeightLoss  ShortnessofBreath  \
# 0                  4        3           4                  2
# ...
